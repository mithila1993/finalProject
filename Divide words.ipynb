# %%
import wordninja
import re

# %%
wordninja.split('derekandersonhellomilksimonwillmake')
# Out:
# ['derek', 'anderson', 'hello', 'milk', 'simon', 'will', 'make']

# %%
a = ['#travel', '#news', '#amsterdam', '#netherlands', '#holland', '#smtravel', '#trip', '#photo', '#marijuana', '#travelers', '#latestnews', '#street', '#htmi', '#colorado', '#pakistan', '#adventure', '#maldives', '#town', '#road', '#jobs', '#aglasem', '#infografia', '#infographic', '#googlenews', '#webdesign', '#vatican', '#popefrancis', '#business', '#amazing', '#chile', '#ttot', '#hhi', '#cnn', '#culture', '#carrefour', '#muscat', '#egypt', '#blog', '#saveswedenswolves', '#backpacking', '#welcome_to_egypt', '#alanailham', '#thailand', '#vmy2014', '#haiti', '#photography', '#church', '#southafrica', '#qatar', '#malaysia', '#hospitality', '#hotels', '#food', '#neworleanswill', '#cruisepeople', '#ofc14', '#china', '#rwanda', '#ecuador', '#keepwolveslisted', '#nysos14', '#expediachat', '#africa', '#job', '#tech', '#socialmedia', '#mashable', '#gdaytourism', '#ireland', '#hampi', '#uganda', '#scotlandhour', '#twitter', '#marketing', '#talent4hire', '#sayfie', '#ff', '#oman', '#caribbean', '#pkmepshouting', '#hotel', '#holiday', '#shuttaijidown', '#latepost', '#goes', '#to', '#jatim', '#follow', '#rt', '#extremadura', '#plasencia', '#italy', '#nouraniummining', '#omaha', '#asean', '#art', '#travelafrica', '#jalanography', '#pcmacl', '#girlstravel', '#christie', '#tourist', '#vacation', '#ob9ja', '#events', '#nogo', '#truetibet', '#tours', '#travelpics', '#travelskills', '#travelkatha', '#tcbudget', '#caribbeannews', '#mydubai', '#savethereef', '#irishbizparty', '#technology', '#gytourismhour', '#spain', '#greatyarmouth', '#nm', '#marrakech', '#fashion', '#singapore', '#discoveroverberg', '#g2b', '#fitur2014', '#welcometoegypt', '#prospects14', '#13', '#thisisegypt', '#beach', '#india', '#jordan', '#health', '#tcot', '#taj', '#tajmahal', '#odisha', '#asia', '#vietnam', '#ldnont', '#responsibletourism', '#vikaskhojyatra', '#feku', '#bills', '#discoveregypt', '#journey', '#shahdag', '#bjpncmeet', '#namo4india', '#namo', '#modi', '#cumbriahour', '#unwto', '#visit', '#travelingsardar', '#assam', '#luxury', '#gcf2014', '#namovision', '#wine', '#france', '#aapdrama', '#etag2014', '#tourismlobbygroup', '#phnompehn', '#cambodia', '#aroundtheworld', '#craft', '#dillihaat', '#madrid', '#enter14', '#dtttawards', '#dttt', '#awards', '#iran', '#iransanctions', '#rouhani', '#iransanctrions', '#tweet4taiji', '#helpcovedolphins', '#btrend', '#angkorwat', '#angkor', '#teambrianmundial', '#team1jonathanperez', '#instagood', '#italy_tourism_guide', '#sadacharyatra', '#happykathnielday', '#doralnews', '#previewlv', '#tourismmatters', '#saudi', '#qatif', '#peru', '#tradefair', '#wineries', '#capitalise', '#chinese', '#germany', '#berlin', '#northkorea', '#kathniel', '#tanzania', '#wtasummit2014', '#gatourism', '#islamabad', '#newyork', '#hostel', '#30yearsofunity', '#syr', '#syracuse', '#armenia', '#swtawards', '#tni', '#doormats', '#indonesia', '#japan', "#mali's", '#google', '#endsharkcull', '#insiders', '#buddhist', '#vipassana', '#auspol', '#superbowl', '#nw', '#adelaide', '#dubai', '#ecotourism', '#guyana', '#alcoblow', '#qanda', '#abc730', '#newakwaibom', '#ilgc14', '#onlyinmn', '#cuba', '#turkey', '#israel', '#storify', '#ftm', '#floatthemoat', '#floattheboat', '#winterlude', '#ottawa', '#winter', '#strongertogether', '#beaches', '#novel', '#development', '#qata13', '#normandy', '#history', '#tdaeroplan', '#agritourism', '#tastourism', '#nabakalebar', '#7rcr', '#bap1004', '#openforbusiness', '#namoinguwahati', '#rgexposesbjp', '#namoinimphal', '#pei', '#romaniastopanimalabuse', '#namoinkerala', '#prévia', '#namoprovedhimself', '#assnat', '#eritrea', '#uk', '#greece', '#vat', '#rsacatalonia', '#rtweek14', '#vatontourism', '#debate', '#chaipecharcha', '#techtourism2014', '#itttourism', '#neknomination', '#tourismchat', '#houston_0998', '#sona2014', '#sona14', '#respcpt', '#sabah', '#tourguide', '#trevelerskesabahkekita', '#taiji', '#sales', '#websitefor1008', '#taba', "#egypt's", '#namoinhp', '#yuva4namo', '#brand', '#dunntrial', '#barossa', '#bigimmigrationrow', '#daehyun', '#humor', '#sustainability', '#g2btaping', '#g2blovewillleadyouback', '#joaquin', '#somet14au', '#utpol', '#florida', '#namoinkar', '#smwlagos', '#tvshow', '#internationaltv', '#streamsports', '#tvhost', '#venezuela', '#namibia', '#music4tourism', '#gmwfestival', '#birthtourism', '#eu', '#maritime', '#samsungdmas', '#sextourisminbrazil', '#albert_stanlie', '#snow', '#world', '#swiss_halley', '#work', '#money', '#namoinarunachal', '#bangalore_hotels', '#routesamericas', '#barcelona', '#qntss2030', '#namoinpunjab', '#wv_tourism', '#effmanifestoofwetdreams', '#dtic2014', '#dticbw', '#augmentedreality', '#layar', '#floral', '#float', '#panagbenga2014', '#citytour', '#wisconsin', '#albania', '#club7canadatours', '#moditva', '#meetingsafrica14', '#teamfollowback', '#eof14', '#laursicagoescuban', '#bahamas', '#wildatlanticway', '#myhnl', '#mr_tourism_kaduna', '#calive14', '#floods', '#ukfloods', '#destinations', '#climbing', '#wanderlust', '#myegypt', '#wigcot', '#libya', '#advertising', '#g2blast4nights', '#reservation', '#satgeo', '#comcec', '#ratw', '#beyondzero', '#itbberlin', '#itbcon14', '#sustainable', '#lupita', '#freshbreak', '#nitbevents', '#tourism_vs_poaching', '#travelgram', '#leisure', '#dmodebate', '#wvdiscgolf', '#discgolf', '#come2egypt', '#romania', '#uae', '#sm', '#mr', '#enjoy', '#international', '#finals', '#naturalstate40', '#puremichigan', '#gr2014eu', '#pmgc14', '#gr2014eutourism', '#tourisme', '#picture', '#up4climate', '#landscape', '#viaggi', '#lovefl', '#stw14', '#reyta', '#aipco14', '#tour', '#pics', '#lionswaitingtodie', '#lionsdeservepride', '#iungalan_', '#destinationlegon', '#500px', '#generationfree', '#eventprofs', '#ttfsummit', '#interhotelchallenge2014', '#traveltuesday', '#teamyamita', '#teamserfeliix', '#oswconf2014', '#apd', '#travelchatsa', '#medical_tourism', '#jef2014', '#metourconf', '#trtc14', '#mainegovconf', '#alabama', '#barbecuebracket', '#architecture', '#pelicanbar', '#ministryoftourism', '#brazilworldcup2014', '#jachat', '#bewizard', '#gusttosoteama', '#biillete', '#kyoto', '#instadaily', '#motel', '#hotelandresorts', '#ios', '#image', '#foto', '#beauty', '#poachersandbutchers', '#8212', '#microstock', '#jamms', '#rai14', '#ayrshirearrangathering2014', '#atp14', '#etw14', '#ttat2014', '#sandiegotourism', '#marbellaishappy', '#whypmmodi', '#umbria', '#namoingaya', '#whymodipm', '#namoinbihar', '#iwinetc', '#georgia', '#22', '#35', '#25', '#bbpilipinas2014coronationnight', '#park', '#parc', '#guell', '#trinidad', '#tweetequine', '#capetown', '#castleofgoodhope', '#memberconnect', '#rtd8', '#genoa', '#tbt', '#thric2014', '#no', '#putinhui', '#360magazine', '#jerusalem', '#edgyfashionmagazine', '#chatreclaim', '#sicily', '#etw2014', '#myohiofun', '#turismo', '#mitzperamon', '#modivision', '#worldaidfaroeislands', '#israeltourism', '#mapuche', '#vaughnlowery', '#urban', '#bjpmanifesto', '#lekhiwinningnewdelhi', '#ab2140', '#ipw14', '#voteyes', '#branson', '#tced', '#crimea', '#futourism', '#8217', '#luiis_3x', '#noplacelikeks', '#asntm2finale', '#sardinia', '#discover_egypt_come_2egypt', '#ugandatourismnight', '#nmid14', '#omexpo2014', '#tourismkt', '#marine_platz', '#munich', '#event', '#stansted', '#dohabus', '#doha', '#kuwait', '#philippines', '#modikiadalat', '#respect', '#deshkaneta', '#newsofindia', '#amysbakingcompany', '#bconnectedconf', '#sadecides', '#medioambiente', '#design', '#shimshal', '#anthropology', '#3alahwa', '#education', '#2014iatc', '#visitbelfast', '#vanshowcase', '#deals', '#onobello', '#canada', '#date360', '#romaniadogkillers', '#byupdate', '#upneedsnamo', '#modisendmetopak', '#juniororteqa', '#mumbai', '#c4news', '#sat', '#bitcoin', '#indiannews', '#visitathensal', '#mexdub', '#mustseeiran', "#iran's", '#cdnhealth', '#otawards', '#sthash', '#staffing', '#chtexchange', '#excited', '#sporttourism', '#nice', '#placemaking', '#culturaltourism', '#maltamassacre', '#globalmexico', '#hhta14', '#travelindia', '#2014lasgpressbriefing', '#touristsboycottromania', '#freechrispackham', '#ephesus', '#sparc2014', '#isaacacosta', '#canadiansealslaughter', '#morocco', '#wengerout', '#straight_egyptian_horses', '#b_polite', '#follobackforfolloback', '#westisbest', '#nttw', '#meranetawill', '#heraldbizawards', '#soccerhubb', '#wpgtourismawards', '#tunisia', '#nlpoli', '#starwars', '#nttw14', '#spring', '#may', '#animal', '#nature', '#wtmafrica', '#irdebate', '#ontheroad', '#traveleffect', '#kenya', '#nttw2014', '#lovewmbg', '#loveva', '#malawi', '#giantplusmalawi', '#noseaworldq102', '#buftourismmatters', '#whereisthefuckingplane', '#bradsmyth', '#schlitterbahnwaterparks', '#texastourism', '#travelmatterssweepstakes', '#africanwildlifesos', '#sealhunt', '#mh370', '#mr_tourism_2014_ekiti', '#forte_elenuftcartiair', '#mammabytkross', '#indaba2014', '#euday2014', '#eurovision', '#sbseurovision', '#exhibition', '#putindie', '#georgiatourism', '#peachstate', '#wonderfulmom', '#veawards2014', '#challenge', '#scooter', '#motorcycle', '#techtalks', '#etourpreneur', '#translation', '#e-tourism', '#usa', '#matachat', '#unreportedworld', '#hbamedtourism', '#buegay', '#tourismsummit', '#explorespace', '#zermatt', '#cedarvalley', "#kenya's", '#asiasummitnz', '#ests2014', '#clearwater', '#stpete', '#rays', '#yeremiito21', '#johan_stars_07', '#thatto', '#sindh', '#livelovelebanon', '#traveling', '#cultural', '#landmark', '#egyptisgreat', '#kenyachinarelations', '#attraction', '#vacaciones', '#brightsea', '#legalization', '#experienceit', '#tyonews', '#lebanon', '#teamkukiito1', '#digital', '#ethicaltourism', '#holidays', '#cutephotos', '#worldcup360', '#ttfoutlook', '#politics', '#obama', '#charleston', '#europeanelections', '#hofpotus', '#opinioncourt', '#fracking', '#cooperstown', '#istanbul', '#capitolcitywednesday', '#jackberry', '#richmondregiontourism', '#tembeakenya', '#kot', '#travelling', '#adventuretime', '#tpsottawa14', '#traveloman', '#zumacabinet', '#cabinet2014', '#wlox', '#wascarx7', '#ck', '#meetsouthafrica', '#jobsite', '#thaicoup', '#rvc2014', '#sectoral', '#europ', '#belgium', '#sand', '#clare', '#security', '#kentucky', '#recruitment', '#babawhileyouwereaway', '#year2wat', '#portugal', '#keralatourismawards', '#iuntaljonatahan', '#museum', '#unwtoknmexico', '#cttindustry', '#tweetni', '#gulfcoast', '#huntsville', '#latestinfo', '#mississippiartscommission', '#toursimindustry', '#syriachems', '#caperay', '#tssymposium', '#rttc', '#euroeco', '#bettycarvercarver', '#nextplorers2', '#tarynpratt', '#hawaii', '#travelist', '#bespoketravel', '#london', '#calabria', '#discoveron', '#honeymoon', '#asbizz', '#olodophotos', '#saverareelephants', '#matterhorn', '#expedition', '#vacationtime', '#globetrottingwino', '#prsatravel', '#nova', '#tlsmitty', '#parenting', '#mei2014', '#beverleyhour', '#ifb2014', '#essex', '#getaway', '#itjobs', '#theitjobs', '#summer', '#tennessee', '#iii', '#explore', '#vbot', '#matutalks', '#ptikpk1year', '#cutenews', '#olodonews', '#mlabrazilbash', '#ugbudget14', '#budget2014', '#knysna', '#ceo', '#announcement', '#glv', '#delaware', '#cur', '#come_visit_egypt', '#turnoffyourgps', '#welfarebudgetkpk', '#mma', '#android', '#mpeketoniattack', '#_deeividx3', '#ctawards14', '#igersmallorca', '#wellness', '#kenyaissafe', '#kyga14', '#healthcare', '#boldtourism', '#teach', '#school', '#wexbizawards', '#odavelymusic', '#traveladdict', '#rwmf2014', '#routesafrica', '#space', '#ajtrial', '#mybudget', '#freeajstaff', '#mamiiguerrero', '#on_swager_1', '#come_to_egypt', '#world_tourism_day', '#traveltip', '#mexico', '#sosafrica', '#peace', '#transport', '#energy', '#buildings', '#california', '#worldcup', '#startup', '#investors', '#bigdata', '#vegas', '#georgiatripplanner', '#eurostat', '#gone', '#smartcontent', '#wackyfaces', '#realfriends', '#happytomeetthem', '#stiproudy', '#sport', '#medical', '#jobnews', '#canadaday', '#queensland', '#sydney', '#encyclojourney', '#goa', '#orlando', '#saransk', '#graphicriver', '#sanssouci', '#marina', '#view', '#scenery', '#travelphoto', '#amish', '#clinic', '#disease', '#lebcommish', '#coffeeculturallandscape', '#wildlife', '#eco', '#bangladesh', '#tourdefrance', '#glenncarey', '#pamarevalo', '#dance', '#mississippiriver', '#czech', '#southcarolina', '#podcast', '#marketsegment', '#telecoms', '#dmforinfo', '#losdelsonido', '#ivanberroa', '#lsa2014', '#garthbrooks', '#selfie', '#cdmx', '#oofest', '#zimbabwe', '#sigueme', '#lmswageer', '#amazon', '#takeahike', '#arts', '#england', '#prkdr', '#iklatestinterview', '#cleveland', '#lebron', '#bubblews', '#centralasiantourism', '#kerala', '#kochi', '#washington', '#victourism14', '#ipad', '#iphone', '#app', '#mexicocity', '#bmta2014', '#archaelogy', '#paestum', '#nhs', '#whatsbrewing', '#unemployment', '#consummate_traveler', '#instatravel', '#portland', '#torbaybf', '#kindle', '#book', '#love', '#social60', '#mh17', '#chicago', '#asmsg', '#mbgn2014', '#seattle', '#video', '#drilling', '#outdoorrec', '#africaatoz', '#opportunities', '#volunteer', '#transformkenyaawards', '#costarica', '#ntia2014', '#idolssa', '#thatwasunexpected', '#beautifulbengal', '#dmai14', '#brazil', '#gaza', '#albanian', '#tourlogy', '#growwatourism', '#trlt', '#tl_chat', '#europe', '#switzerland', '#quintanaroo', '#xelha', '#pictureoftheday', '#followme', '#boat', '#poland', '#holocaust', '#kuuky__frez', '#paris', '#msgct14', '#welcometweet', '#aa', '#golf', '#viewpoints', '#tourismrecovery', '#indiatravelawards', '#nebo', '#inta14', '#weekend', '#waterfal', '#stopicelandicwhaling', '#isupportmodi', '#elizabethbecker', '#fun', '#dental', '#animals', '#ethics', '#sea', '#baltimore', '#software', '#md', '#ski', '#skiing', '#biking', '#flyfishing', '#kampalabiennale', '#yorkshireday', '#vsco', '#aspadogkillers', '#closingceremony', '#commonwealthgames', '#glasgow2014', '#bbcglasgow2014', '#aes2014', '#getaways', '#medicalmarijuana', '#cannabis', '#thc', '#incredibleindia', '#places', '#expediaviewfinder', '#svaneti', '#ipw4', '#photooftheday', '#island', '#wtd2014', '#canon', '##tourism', '#ofamily', '#perfection', '#uktvneedsoutlander', '#outlander', '#hccta14', '#photoshoot', '#headfirst', '#youthassembly', '#uzbekistan', '#throwbackthursday', '#travelnews', '#satsa2014', '#travel_videos', '#liftgazablockade', '#boycott_tourism_to_egypt', '#askingforafriend', '#wrexham', '#didyouknow', '#westerncape', '#skupdates', '#worldtravelawards2014', '#city', '#theatre', '#cavan', '#disabilities', '#pr', '#riomas20_bogota', '#getbritainworking', '#bag', '#pullandbear', '#socialmediapicks', '#buddhism', '#buddha', '#nepal', '#spiritual', '#ghana', '#phdevt', '#imcc3', '#shark', '#cananbis', '#yeson2', '#winnibssplc200k', '#launceston', '#asurumaa', '#wesupportsez', '#nctawards', '#most', '#googlealerts', '#fcaccphotomegahunt2014', '#teamhellcat', '#lostpix', '#4corners', '#fightforthereef', '#congresskzn', '#ebola', '#kid', '#nyc', '#indyref', '#iceland', '#pinellas', '#chinese_regime', '#donors', '#huang_jiefu', '#funny', '#rape', '#lfc', '#suicide', '#rapesmall4bjp', '#ebolafreegambia', '#biza', '#bigministersmallrape', '#darktourism', '#cashinin', '#ent_redefineddotcom', '#wales', '#save', '#venice', '#mass', '#self', '#cusco', '#sex', '#turkistan', '#esto14', '#fife', '#satourismmonth', '#nz', '#tia', '#unngo2014', '#mahatourism', '#diving', '#cascoantiguo', '#htaconf2014', '#tour4cause', '#economy', '#frankfurt', '#main', '#islamic', '#airline', '#petretourist', '#louisiana', '#cloudy', '#chichester', '#bctourism', '#johnkeener', '#kathleencartland', '#grindstop', '#cruise', '#tourismmonth', '#phoenixatone', '#phoenix', '#oausupport', '#foreigncorrespondent', '#wwweek', '#ibeacon', '#mahayouth', '#etas14', '#apps', '#talktv', '#youthsoccer', '#lilizelaawards', '#balafalls', '#wemeanbusiness', '#wttc', '#cyprus', '#greek', '#gno', '#tahrirdialogue', '#employment', '#reshuffle', '#iottt', '#soundcloud', '#tbex', '#tbexcancun', '#diamonds', '#onthedraw', '#hamont', '#eaa2014', '#t9njobs', '#lifestyle', '#qom', '#ahwaz', '#daryeknegahnews', '#mahainvest', '#craftbeer', '#bangalo', '#destq', '#ableg', '#cosmetics', '#cpcueropornoqrafico', '#lozteletobiiz', '#sweden', '#discoverpv', '#scotland', "#scotland's", '#music', '#gcu', '#infogafia', '#life', '#celebratejax', '#ilovejax', '#sotic2014', '#maxvelocity', '#salaj', '#wedf', '#duchybizhour', '#termtime', '#wpg14', '#tasnim', '#getme2george', '#fuhnspot', '#train', '#kelowna', '#pattaya', '#youthccconf', '#eculture', '#euro2020', '#igtravel', '#wildhorses', '#entrepreneurship', '#t4us', '#dc', '#picoftheday', '#mahaurban', '#gc14', '#gadventures', '#atanyu', '#turnitupwv', '#austin', '#africanfashion', '#adireepr', '#afwny', '#ottvote', '#lovedublin', '#wtvunispeak', '#dorsettourismawards', '#quito', '#smwmumbai', '#wystc2014', '#kx2014', '#worldtourismday', '#pa', '#top5ads', '#mbtourismawards', '#australia', '#fsn2014', '#cork', '#hamas', '#modiatmadison', '#modiinamerica', '#addisabeba', '#economies', '#mahatransport', '#txsummit14', '#modiatcfr', '#topoli', '#ephearings2014', '#etea14', '#empleo', '#trabajo', '#iraq', '#jyj', '#italy365', '#branding', '#viaggio', '#globalcork', '#davidmiller', '#hannahwitheridge', '#kohtao', '#kimjaejoong', '#unwtopracticum', '#backseat', '#magallanes', '#mahaemployment', '#maharashtra', '#euwildernessacademy', '#png', '#bhutan', '#thimphu', '#mallocafeelings', '#youtheo', '#bishunpur', '#ecrt14', '#dentalcare', '#wtmadeira', '#2014atws', '#miss', '#adobeedex', '#mkte2014', '#wariskite', '#movies', '#television', '#southsummit14', '#funtimeske', '#phirsecongress', '#staoctobermeet', '#industry', '#ptawards2014', '#hetourism', '#skiftforum', '#ets14', '#vac2014', '#bestcolleagues', '#tourismnetwork', '#tla', '#group', '#party', '#comedy', '#mahawithcongress', '#hellodavao', '#hospitalityawards', '#budget2015', '#msglobalph', '#congressformaharashtra', '#backpackers', '#itvcoverup', '#crimecon', '#prssanc', '#sugar', '#maharashtra1st', '#travelphotocontest', '#denmark', '#francia', '#ktc14', '#pga', '#matic', '#ligakam', '#luxhosp', '#wwim10', '#stopyulin2015', '#budget15', '#hospitalityawards2014', '#responsible', '#ruralwomen', '#wef', '#cruises', '#travelphotography', '#okoatourismke', '#nycanadasummit', '#ghp2014', '#fiwarems', '#bucks2014', '#dayinthelifens', '#margate', '#barbados', '#rtawards15', '#lovewhitsundays', '#wtba14', '#jamaica', '#tonight', '#farrakhan', '#hdoa14', '#lahorestandswithpat', '#d4all2014', '#moon', '#gigatowngis', '#artn14', '#taic', '#accessible', '#trekking', '#conference', '#glendalecvb', '#athensstorytellingfestival', '#lgbt', '#norwegiandtc', '#bbtw', '#tourismforpakistan', '#mbta2014', '#kto', '#ktomanila', '#wowkoreasupporters', '#futuristicaviation', '#futurespacetourismtransportation', '#veevents', '#bbcqt', '#technews', '#myottawa', '#itc14', '#magovconf', '#usworld', '#ukuselaekapa', '#plettitsafeeling', '#travelsocialgood', '#visiting', '#vtagala2014', '#ethiopia', '#unday', '#wata14', '#cooking', '#gigatownwanaka', '#kimsoohyun', '#mmte', '#goldcoast', '#entertainment', '#synergy', '#w2ny', '#giantflag', '#wide', '#libertyopener', '#cttagm', '#lovecapetown', '#ptigovernancemeans', '#banmedicaltourism', '#empowerment', '#women', '#absummit', '#boms2014', '#visit_egypt', '#loveegypt', '#czechtourismforum', '#msvu', '#ap10things', '#wtm14', '#savings', '#spaceshiptwo', '#resort', '#travelblogger', '#science', '#humble', '#effort', '#ttagm', '#argentina', '#tourismdayatqp', '#wtm2014', '#italian', '#bc', '#manzanillo', '#crash', '#winseattle', '#10factsaboutpakistan', '#lta14', '#cta14', '#eavoices', '#biketourism14', '#mnclimate2014', '#northernfutures', '#nvleg', '#ef', '#geek', '#tastourismawards', '#cdnwinetourism', '#reformsinnayakp', '#wired', '#cornwall', '#mexicodf', '#gigatowndun', '#gigatowndunedin', '#neeta2014', '#lbconf14', '#changepenang', '#ita2015', '#lets', '#bneglobalcafe', '#gadhimai', '#ots14', '#founditincv', '#36ng', '#tristar', '#futatoday', '#wtc14', '#toddhunter', '#corpuschristi', '#screentourism', '#justice4saiful', '#opkillingbay', '#jpolyboycott', '#prague', '#tmtravelawards']

# %%
for x in a:
    y = re.sub('([#])|([^a-zA-Z])',' ',x)
    z = wordninja.split(y)
    for b in z:
        print(b, end =" ")
    print()
# Out:
# travel
# news
# amsterdam
# netherlands
# holland
# sm travel
# trip
# photo
# marijuana
# travelers
# latest news
# street
# htm i
# colorado
# pakistan
# adventure
# maldives
# town
# road
# jobs
# a glas em
# in fog rafi a
# info graphic
# google news
# web design
# vatican
# pope francis
# business
# amazing
# chile
# t to t
# h hi
# cnn
# culture
# carrefour
# muscat
# egypt
# blog
# save sweden s wolves
# backpacking
# welcome to egypt
# alana ilham
# thailand
# v my
# haiti
# photography
# church
# south africa
# qatar
# malaysia
# hospitality
# hotels
# food
# new orleans will
# cruise people
# of c
# china
# rwanda
# ecuador
# keep wolves listed
# ny sos
# ex pedia chat
# africa
# job
# tech
# social media
# mash able
# g day tourism
# ireland
# hampi
# uganda
# scotland hour
# twitter
# marketing
# talent hire
# say fie
# ff
# oman
# caribbean
# pk mep shouting
# hotel
# holiday
# shut taiji down
# late post
# goes
# to
# jati m
# follow
# rt
# extremadura
# pla sen cia
# ...
